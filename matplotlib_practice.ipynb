# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.3.4'

# %%
# %matplotlib inline

# %%
# Import dependencies.
import matplotlib.pyplot as plt

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot
plt.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.plot(x_axis, y_axis)

fig, ax = plt.subplots(figsize=(2, 2))

# Create labels for the x and y axes.
ax.plot(x, y, marker="D", color="green", label='Boston')

# Create labels for the x and y axes.
ax.set_xlabel('Date')
ax.set_ylabel('Fare($)')

# Set the x limit and y limit
ax.set_xlim(Jan, Dec)
ax.set_ylim(0, 45)

# Add a title
ax.set_title("PyBer Fare by Month")

# Change the line color to green, marker to diamond, line width to 2 points, legend for the city of Boston.
ax.plot(x_axis, y_axis, , linewidth=2 )

# Add grid lines. 
ax.legend()
# Out:
#   File "<ipython-input-38-853445016bc6>", line 22
#     ax.plot(x_axis, y_axis, , linewidth=2 )
#                             ^
# SyntaxError: invalid syntax

# %%
# Create the plot with ax.plt()
fig = plt.figure()
ax = fig.add_subplot()

# %%
# Create the plot with ax.plt()
ax = plt.axes()
ax.plot(x_axis, y_axis)

# %%
# Create the plot.
plt.plot(x_axis, y_axis)
plt.show()

# %%
# Create the plot and add a label for the legend.
plt.plot(x_axis, y_axis, label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y limit between 0 and 45.
plt.ylim(0, 45)
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()

# %%
# Create the plot.
plt.plot(x_axis, y_axis, marker="*", color="blue", linewidth=2, label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y limit between 0 and 45.
plt.ylim(0, 45)
# Create a title.
plt.title("PyBer Fare by Month")
# Add a grid.
plt.grid()
# Add the legend.
plt.legend()

# %%
# Create the ax.plot()
# ax = plt.axes()
fig, ax = plt.subplots(figsize=(5,5))

# Create labels for the x and y axes.
ax.plot(x_axis, y_axis, marker="D", color="green", label='Boston')

# Create labels for the x and y axes.
ax.set_xlabel('Date')
ax.set_ylabel('Fare($)')

# Set the x limit and y limit
ax.set_xlim("Jan", "Dec")
ax.set_ylim(0, 45)

# Add a title
ax.set_title("PyBer Fare by Month")

# Change the line color to green, marker to diamond, line width to 2 points, legend for the city of Boston.
ax.plot(x_axis, y_axis,linewidth=2 )

# Add grid lines. 
ax.legend(loc=3)
ax.grid(b=True)

# %%
# Create the plot
plt.bar(x_axis, y_axis)
# Create the plot.
plt.bar(x_axis, y_axis, color="green", label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()

# %%
# Create the plot
plt.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot
plt.barh(y_axis, x_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
matplotlib.pyplot.barh(x_axis, y_axis, color="magenta", label='Boston')
plt.gca().invert_yaxis()
plt.ylabel("Date")
plt.xlabel("Fare($)")
plt.title("PyBer Fare by Month")
plt.legend()

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.bar(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
plt.bar(x_axis, y_axis, color="black", label='New York')
# Out:
# <BarContainer object of 12 artists>

# %%
ax.bar(x_axis, y_axis, color="black", label='New York')
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis, label='Chicago', color="cyan")
ax.set_ylabel('Date')
ax.set_xlabel('Fare($)')
ax.set_title("PyBer Fare by Month")
plt.gca().invert_yaxis()
ax.legend()

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.barh(y_axis, x_axis)
# Out:
# <BarContainer object of 12 artists>
